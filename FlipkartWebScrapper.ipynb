# %%
import requests

# %%
url = 'https://api.openweathermap.org/data/2.5/weather?q=Jaipur&APPID=2afcb589603e94453f87e8b672697256'

# %%
data = requests.get(url).json()

# %%
print(data)
# Out:
# {'coord': {'lon': 75.8167, 'lat': 26.9167}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 295.77, 'feels_like': 295.76, 'temp_min': 295.77, 'temp_max': 295.77, 'pressure': 1012, 'humidity': 64}, 'visibility': 3500, 'wind': {'speed': 2.57, 'deg': 220}, 'clouds': {'all': 40}, 'dt': 1679545050, 'sys': {'type': 1, 'id': 9170, 'country': 'IN', 'sunrise': 1679533084, 'sunset': 1679576931}, 'timezone': 19800, 'id': 1269515, 'name': 'Jaipur', 'cod': 200}

# %%
print(data['main']['temp'])
# Out:
# 295.77

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uopen

# %%
url = 'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
x = uopen(url)
html_page = x.read()
x.close()
new_page = soup(html_page, 'html.parser')

# %%
print(new_page)
# Out:
# <!DOCTYPE html>
# ...

# %%
cont = new_page.findAll('div', {'class' : '_13oc-S'})
cont
# Out:
# [<div class="_13oc-S"><div data-id="MOBGHWFHABH3G73H" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&amp;lid=LSTMOBGHWFHABH3G73HVXY5AV&amp;marketplace=FLIPKART&amp;q=iphone&amp;store=tyy%2F4io&amp;spotlightTagId=BestsellerId_tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=8d39750f-6e32-4498-98e4-3dfc44b9e419.MOBGHWFHABH3G73H.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=tbi13x0xgw0000001679545097096&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank"><div></div><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 14 (Starlight, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/m/o/b/-original-imaghx9qkugtbfrn.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8
# ...

# %%
len(cont)
# Out:
# 24

# %%
soup.prettify(cont[0])
# Out:
# '<div class="_13oc-S">\n <div data-id="MOBGHWFHABH3G73H" style="width:100%">\n  <div class="_2kHMtA">\n   <a class="_1fQZEK" href="/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&amp;lid=LSTMOBGHWFHABH3G73HVXY5AV&amp;marketplace=FLIPKART&amp;q=iphone&amp;store=tyy%2F4io&amp;spotlightTagId=BestsellerId_tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=8d39750f-6e32-4498-98e4-3dfc44b9e419.MOBGHWFHABH3G73H.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=tbi13x0xgw0000001679545097096&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank">\n    <div>\n    </div>\n    <div class="MIXNux">\n     <div class="_2QcLo-">\n      <div>\n       <div class="CXW8mj" style="height:200px;width:200px">\n        <img alt="APPLE iPhone 14 (Starlight, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/m/o/b/-original-imaghx9qkugtbfrn.jpeg?q=70"/>\n       </div>\n      </div>\n     </
# ...

# %%
for cont1 in cont:
  title = cont1.div.img["alt"]
  title = title.replace(",","|")

  price = cont1.findAll('div',{'class':'_30jeq3 _1_WHN1'})
  price = price[0].text

  #ratings = cont1.findAll('div',{'class':'_3LWZlK'})
  #ratings = ratings[0].text

  print(title , price)
# Out:
# APPLE iPhone 14 (Starlight| 128 GB) ₹71,999
# APPLE iPhone 14 Plus (Midnight| 128 GB) ₹80,999
# APPLE iPhone 14 Plus (Starlight| 128 GB) ₹80,999
# APPLE iPhone 14 Plus (Purple| 128 GB) ₹80,999
# APPLE iPhone 14 (Purple| 128 GB) ₹71,999
# APPLE iPhone 14 (Blue| 128 GB) ₹71,999
# APPLE iPhone 13 (Green| 128 GB) ₹61,999
# APPLE iPhone 11 (White| 64 GB) ₹40,999
# APPLE iPhone 14 Plus (Blue| 128 GB) ₹80,999
# APPLE iPhone 13 (Midnight| 128 GB) ₹61,999
# APPLE iPhone 13 (Pink| 128 GB) ₹61,999
# APPLE iPhone 11 (Black| 64 GB) ₹40,999
# APPLE iPhone 13 (Starlight| 128 GB) ₹61,999
# APPLE iPhone 14 ((PRODUCT)RED| 128 GB) ₹71,999
# APPLE iPhone 14 (Blue| 256 GB) ₹81,999
# APPLE iPhone 14 Plus ((PRODUCT)RED| 128 GB) ₹80,999
# APPLE iPhone 14 (Starlight| 256 GB) ₹81,999
# APPLE iPhone 14 (Midnight| 128 GB) ₹71,999
# APPLE iPhone 11 (Black| 128 GB) ₹46,999
# APPLE iPhone 14 Plus (Purple| 256 GB) ₹90,999
# APPLE iPhone 11 (White| 128 GB) ₹46,999
# APPLE iPhone 13 (Blue| 128 GB) ₹61,999
# ...

# %%
import csv 

header = ['Title', 'Price']
data = [cont2.title, cont2.price]

for cont2 in cont:
    with open('FlipcartWebScraperDataset.csv', '+a', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'D:\Web_Scraping\flipcartWebScraperDataset.csv')

print(df)
# Out:
#                                         Title    Price
# 0    APPLE iPhone 14 Plus (Starlight| 256 GB)  ₹90,999
# 1                                       Title    Price
# 2    APPLE iPhone 14 Plus (Starlight| 256 GB)  ₹90,999
# 3                                       Title    Price
# 4    APPLE iPhone 14 Plus (Starlight| 256 GB)  ₹90,999
# ..                                        ...      ...
# 132                                       NaN      NaN
# 133                                     Title    Price
# 134                                       NaN      NaN
# 135                                     Title    Price
# 136                                       NaN      NaN
#
# [137 rows x 2 columns]
